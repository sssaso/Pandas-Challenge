# %%
import pandas as pd

# %%
file_to_load = "Resources/purchase_data.csv"
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#Q1.Total number of players #########################################

total_players = purchase_data["SN"].nunique()
totalPlayers_df = pd.DataFrame({"Total Players":[total_players]})  
totalPlayers_df.head()
# Out:
#    Total Players
# 0            576

# %%
#Q2 Purchasing_Analysis Total ##############################################

UniqItems = purchase_data["Item Name"].unique() # <-- series
AvgPurPrice = purchase_data["Price"].mean() # default axis = 0, meaning row, vertically
Num_Purchase = purchase_data["Purchase ID"].count() # default axis = 0
totalRev = purchase_data["Price"].sum() # default axis = 0

Purchasing_Analysis_df =pd.DataFrame({"Number of Unique Items":len(UniqItems),
                                    "Average Price":"${:,.2f}".format(AvgPurPrice),
                                    "Number of Purchases": [Num_Purchase],
                                    "Total Revenue":"${:,.2f}".format(totalRev)})
Purchasing_Analysis_df
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780     $2,379.77

# %%
#Q3 Gender Demographics #######################################################

male_df=purchase_data.loc[purchase_data["Gender"]=="Male"] # <-- filtered df if the condition met
female_df=purchase_data.loc[purchase_data["Gender"]=="Female"]
others_df =purchase_data.loc[purchase_data["Gender"]=="Other / Non-Disclosed"]

#malePlayers = len(male_df["SN"].unique())
malePlayers = male_df["SN"].nunique()
#femalePlayers = len(female_df["SN"].unique())
femalePlayers = female_df["SN"].nunique()
#others = len(others_df["SN"].unique())
others = others_df["SN"].nunique()

malePerc = "{:.2%}".format(malePlayers/total_players)
femalePerc = "{:.2%}".format(femalePlayers/total_players)
othersPerc = "{:.2%}".format(others/total_players)

genderDemog_df = pd.DataFrame({"Total Count":[malePlayers,femalePlayers, others], 
                              "Percentage of Players":[malePerc, femalePerc, othersPerc]}, 
                             index=["Male","Female", "Other/Non-Disclosed"])
genderDemog_df
# Out:
#                      Total Count Percentage of Players
# Male                         484                84.03%
# Female                        81                14.06%
# Other/Non-Disclosed           11                 1.91%

# %%
#Q4 Purchasing Analysis by Gender ############################################

#  Purchase Count #
purchase_data['Count'] = 1
Purchase_Count = purchase_data.groupby(["Gender"]).count()['Count']
purchaseCount_male = Purchase_Count["Male"]
purchaseCount_female = Purchase_Count["Female"]
purchaseCount_others =Purchase_Count["Other / Non-Disclosed"]

#  Average Purchase Price #
avg_Purchase_price = purchase_data.groupby(["Gender"]).mean()['Price']
avg_Purchase_price_male = avg_Purchase_price["Male"]
avg_Purchase_price_female = avg_Purchase_price["Female"]
avg_Purchase_price_others = avg_Purchase_price["Other / Non-Disclosed"]

#  Total Purchase Value #
tot_Purchase_value = purchase_data.groupby(["Gender"]).sum()['Price']
tot_Purchase_value_male = tot_Purchase_value["Male"]                      
tot_Purchase_value_female = tot_Purchase_value["Female"]  
tot_Purchase_value_others = tot_Purchase_value["Other / Non-Disclosed"]

#  Average Purchase Total per Person by Gender #
avg_tot_pur_male = tot_Purchase_value_male / malePlayers
avg_tot_pur_female = tot_Purchase_value_female / femalePlayers
avg_tot_pur_others = tot_Purchase_value_others / others

purchase_byGender_df = pd.DataFrame({"Purchase Count":[purchaseCount_male,purchaseCount_female, purchaseCount_others], 
                              "Average Purchase Price":["${:.2f}".format(avg_Purchase_price_male), 
                                                        "${:.2f}".format(avg_Purchase_price_female), 
                                                        "${:.2f}".format(avg_Purchase_price_others)],
                               "Total Purchase Value":["${:,.2f}".format(tot_Purchase_value_male),
                                                       "${:,.2f}".format(tot_Purchase_value_female),
                                                       "${:,.2f}".format(tot_Purchase_value_others)],
                                 "Avg Total Purchase per Person":["${:.2f}".format(avg_tot_pur_male),
                                                                  "${:.2f}".format(avg_tot_pur_female),
                                                                  "${:.2f}".format(avg_tot_pur_others)]
                                  }, 
                             index=["Male","Female", "Other/Non-Disclosed"])
purchase_byGender_df
# Out:
#                      Purchase Count Average Purchase Price  \
# Male                            652                  $3.02
# Female                          113                  $3.20
# Other/Non-Disclosed              15                  $3.35
#
#                     Total Purchase Value Avg Total Purchase per Person
# Male                           $1,967.64                         $4.07
# Female                           $361.94                         $4.47
# Other/Non-Disclosed               $50.19                         $4.56

# %%
#Q5  Age Demographics ###############################################

#Establish bins for ages   
bins = [0,9,14,19,24,29,34,39,60]
names = ["<10", "10~14","15~19","20~24", "25~29", "30~34", "35~39", "40+"]

purchase_data["Age group"]=pd.cut(purchase_data["Age"],bins, labels=names, include_lowest = True)

#Calculate the numbers and percentages by age group

grpBy_ageGroup = purchase_data.groupby("Age group")

playerCount=grpBy_ageGroup["SN"].nunique()
perc_of_player = playerCount/total_players

#Create a summary data frame to hold the results
summary_df=pd.DataFrame({"Total Count":playerCount,
                         "Percentage of Players":perc_of_player})

#Optional: round the percentage column to two decimal points 
summary_df.head(8).style.format({"Percentage of Players":"{:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_517583ee_a78f_11ea_85cf_f80f412b8562" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age group</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_517583ee_a78f_11ea_85cf_f80f412b8562level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_517583ee_a78f_11ea_85cf_f80f412b8562level0_row1" class="row_heading level0 row1" >10~14</th>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row1_col0" class="data row1 col0" >22</td>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row1_col1" class="data row1 col1" >3.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_517583ee_a78f_11ea_85cf_f80f412b8562level0_row2" class="row_heading level0 row2" >15~19</th>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row2_col0" class="data row2 col0" >107</td>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row2_col1" class="data row2 col1" >18.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_517583ee_a78f_11ea_85cf_f80f412b8562level0_row3" class="row_heading level0 row3" >20~24</th>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row3_col0" class="data row3 col0" >258</td>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row3_col1" class="data row3 col1" >44.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_517583ee_a78f_11ea_85cf_f80f412b8562level0_row4" class="row_heading level0 row4" >25~29</th>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row4_col0" class="data row4 col0" >77</td>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row4_col1" class="data row4 col1" >13.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_517583ee_a78f_11ea_85cf_f80f412b8562level0_row5" class="row_heading level0 row5" >30~34</th>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row5_col0" class="data row5 col0" >52</td>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row5_col1" class="data row5 col1" >9.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_517583ee_a78f_11ea_85cf_f80f412b8562level0_row6" class="row_heading level0 row6" >35~39</th>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row6_col0" class="data row6 col0" >31</td>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row6_col1" class="data row6 col1" >5.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_517583ee_a78f_11ea_85cf_f80f412b8562level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row7_col0" class="data row7 col0" >12</td>
#                         <td id="T_517583ee_a78f_11ea_85cf_f80f412b8562row7_col1" class="data row7 col1" >2.08%</td>
#             </tr>
#     </tbody></table>

# %%
#Q6 Purchasing Analysis by Age #########################################  

p_count = grpBy_ageGroup["Count"].count()
avg_pPrice = grpBy_ageGroup["Price"].mean()
tot_pValue = grpBy_ageGroup["Price"].sum()
avg_totP_p = tot_pValue/playerCount

#Create a summary data frame to hold the results
Purchase_analysis_age_df=pd.DataFrame({"Purchase Count":p_count,
                         "Average Purchase Price":avg_pPrice,
                        "Total Purchase Value":tot_pValue,
                        "Avg Total Purchase per Person":avg_totP_p})

#Optional: round the percentage column to two decimal points 
Purchase_analysis_age_df.head(8).style.format({"Average Purchase Price":"${:.2f}",
                                               "Total Purchase Value":"${:.2f}",
                                               "Avg Total Purchase per Person":"${:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_84920a62_a78f_11ea_aa04_f80f412b8562" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_84920a62_a78f_11ea_aa04_f80f412b8562level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_84920a62_a78f_11ea_aa04_f80f412b8562level0_row1" class="row_heading level0 row1" >10~14</th>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row1_col0" class="data row1 col0" >28</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_84920a62_a78f_11ea_aa04_f80f412b8562level0_row2" class="row_heading level0 row2" >15~19</th>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row2_col0" class="data row2 col0" >136</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_84920a62_a78f_11ea_aa04_f80f412b8562level0_row3" class="row_heading level0 row3" >20~24</th>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row3_col0" class="data row3 col0" >365</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row3_col2" class="data row3 col2" >$1114.06</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_84920a62_a78f_11ea_aa04_f80f412b8562level0_row4" class="row_heading level0 row4" >25~29</th>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row4_col0" class="data row4 col0" >101</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_84920a62_a78f_11ea_aa04_f80f412b8562level0_row5" class="row_heading level0 row5" >30~34</th>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row5_col0" class="data row5 col0" >73</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_84920a62_a78f_11ea_aa04_f80f412b8562level0_row6" class="row_heading level0 row6" >35~39</th>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row6_col0" class="data row6 col0" >41</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_84920a62_a78f_11ea_aa04_f80f412b8562level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row7_col0" class="data row7 col0" >13</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_84920a62_a78f_11ea_aa04_f80f412b8562row7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %%
#Q7 Top Spenders #########################################################

#groupby SN
grpBy_SN = purchase_data.groupby(['SN'])
grpBy_SN_pCount = grpBy_SN['Count'].count()
grpBy_SN_aPrice = grpBy_SN['Price'].mean()
grpBy_SN_tPurchase = grpBy_SN['Price'].sum()

#make dataframe
topSpenders_df = pd.DataFrame({"Purchase Count":grpBy_SN_pCount,
                            "Average Purchase Price":grpBy_SN_aPrice,
                            "Total Purchase Value":grpBy_SN_tPurchase} 
                           )

#sort by total purchase value decending
topSpenders_sorted_df=topSpenders_df.sort_values('Total Purchase Value', ascending =False)

#format
topSpenders_sorted_formatted=topSpenders_sorted_df.head(5).style.format({"Average Purchase Price":"${:,.2f}",
                                    "Total Purchase Value":"${:,.2f}"})
topSpenders_sorted_formatted
# Out:
# <style  type="text/css" >
# </style><table id="T_aeb928b0_a78f_11ea_a485_f80f412b8562" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aeb928b0_a78f_11ea_a485_f80f412b8562level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row0_col1" class="data row0 col1" >$3.79</td>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row0_col2" class="data row0 col2" >$18.96</td>
#             </tr>
#             <tr>
#                         <th id="T_aeb928b0_a78f_11ea_a485_f80f412b8562level0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row1_col1" class="data row1 col1" >$3.86</td>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row1_col2" class="data row1 col2" >$15.45</td>
#             </tr>
#             <tr>
#                         <th id="T_aeb928b0_a78f_11ea_a485_f80f412b8562level0_row2" class="row_heading level0 row2" >Chamjask73</th>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row2_col1" class="data row2 col1" >$4.61</td>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row2_col2" class="data row2 col2" >$13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_aeb928b0_a78f_11ea_a485_f80f412b8562level0_row3" class="row_heading level0 row3" >Iral74</th>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row3_col1" class="data row3 col1" >$3.40</td>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row3_col2" class="data row3 col2" >$13.62</td>
#             </tr>
#             <tr>
#                         <th id="T_aeb928b0_a78f_11ea_a485_f80f412b8562level0_row4" class="row_heading level0 row4" >Iskadarya95</th>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row4_col1" class="data row4 col1" >$4.37</td>
#                         <td id="T_aeb928b0_a78f_11ea_a485_f80f412b8562row4_col2" class="data row4 col2" >$13.10</td>
#             </tr>
#     </tbody></table>

# %%
#Q8 Most Popular Items #######################################################

#Group by Item ID and Item Name.
grpBy_Item = purchase_data.groupby(["Item ID", "Item Name"])

#Obtain purchase count, item price, and total purchase value
purCount = grpBy_Item['Count'].count()
priceCount = grpBy_Item['Price'].count()
tot_pur_value = grpBy_Item['Price'].sum()
itemPrice = tot_pur_value/priceCount

#Create a summary data frame to hold the results
Items_df = pd.DataFrame({"Purchase Count":purCount ,
                               "Item Price":itemPrice ,
                               "Total Purchase Value":tot_pur_value})

#Sort the purchase count column in descending order
mostPopItems_sorted_df = Items_df.sort_values("Purchase Count", ascending =False)
#format and preview
mostPopItems_sorted_formatted = mostPopItems_sorted_df.head(5).style.format(
    {"Item Price":"${:,.2f}","Total Purchase Value":"${:,.2f}"})
mostPopItems_sorted_formatted
# Out:
# <style  type="text/css" >
# </style><table id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562level0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562level0_row2" class="row_heading level0 row2" >145</th>
#                         <th id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562level1_row2" class="row_heading level1 row2" >Fiery Glass Crusader</th>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row2_col1" class="data row2 col1" >$4.58</td>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row2_col2" class="data row2 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562level0_row3" class="row_heading level0 row3" >132</th>
#                         <th id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562level1_row3" class="row_heading level1 row3" >Persuasion</th>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row3_col1" class="data row3 col1" >$3.22</td>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row3_col2" class="data row3 col2" >$28.99</td>
#             </tr>
#             <tr>
#                         <th id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562level0_row4" class="row_heading level0 row4" >108</th>
#                         <th id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562level1_row4" class="row_heading level1 row4" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row4_col0" class="data row4 col0" >9</td>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row4_col1" class="data row4 col1" >$3.53</td>
#                         <td id="T_da9f574c_a78f_11ea_a5dc_f80f412b8562row4_col2" class="data row4 col2" >$31.77</td>
#             </tr>
#     </tbody></table>

# %%
#9 Most Profitable Items #################################################

#Sort the above table by total purchase value in descending order
mostProfitItems_sorted_df = Items_df.sort_values("Total Purchase Value", ascending =False)

#preview
mostProfitItems_sorted_formatted = mostProfitItems_sorted_df.head(5).style.format(
    {"Item Price":"${:,.2f}","Total Purchase Value":"${:,.2f}"})
mostProfitItems_sorted_formatted
# Out:
# <style  type="text/css" >
# </style><table id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562level0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562level0_row2" class="row_heading level0 row2" >82</th>
#                         <th id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562level1_row2" class="row_heading level1 row2" >Nirvana</th>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row2_col1" class="data row2 col1" >$4.90</td>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row2_col2" class="data row2 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562level0_row3" class="row_heading level0 row3" >145</th>
#                         <th id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562level1_row3" class="row_heading level1 row3" >Fiery Glass Crusader</th>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row3_col1" class="data row3 col1" >$4.58</td>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row3_col2" class="data row3 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562level0_row4" class="row_heading level0 row4" >103</th>
#                         <th id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562level1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row4_col0" class="data row4 col0" >8</td>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row4_col1" class="data row4 col1" >$4.35</td>
#                         <td id="T_cf5727c0_a78d_11ea_ba0f_f80f412b8562row4_col2" class="data row4 col2" >$34.80</td>
#             </tr>
#     </tbody></table>
